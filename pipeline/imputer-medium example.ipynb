# %%
#https://towardsdatascience.com/creating-custom-transformers-for-sklearn-pipelines-d3d51852ecc1
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted
# The ColumnsSelector class inherits from the sklearn.base classes 
# (BaseEstimator, TransformerMixin). This makes it compatible with 
# scikit-learn’s Pipelines
class ColumnsSelector(BaseEstimator, TransformerMixin):
    # initializer 
    def __init__(self, columns):
        # save the features list internally in the class
        self.columns = columns
        
    def fit(self, X, y = None):
        return self
    def transform(self, X, y = None):
        # return the dataframe with the specified features
        return X[self.columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
df = pd.read_csv('train.csv')
df = df[['Survived','Pclass','Sex','Age','Fare','Embarked']]
X = df.iloc[:,1:]
y = df.iloc[:,0]
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                  test_size = 0.3, 
                                                  stratify = y, 
                                                  random_state = 0)
X_train
# Out:
#      Pclass     Sex   Age     Fare Embarked
# 231       3    male  29.0   7.7750        S
# 836       3    male  21.0   8.6625        S
# 639       3    male   NaN  16.1000        S
# 389       2  female  17.0  12.0000        C
# 597       3    male  49.0   0.0000        S
# ..      ...     ...   ...      ...      ...
# 131       3    male  20.0   7.0500        S
# 490       3    male   NaN  19.9667        S
# 838       3    male  32.0  56.4958        S
# 48        3    male   NaN  21.6792        C
# 80        3    male  22.0   9.0000        S
#
# [623 rows x 5 columns]

# %%
from sklearn.pipeline import Pipeline
numeric_transformer = Pipeline(steps=[
    ('columns selector', ColumnsSelector(['Age','Fare'])),
])

# %%
numeric_transformer.fit(X_train)
# Out:
# Pipeline(steps=[('columns selector', ColumnsSelector(columns=['Age', 'Fare']))])

# %%
numeric_transformer.transform(X_train)#先fit再transform
# Out:
#       Age     Fare
# 231  29.0   7.7750
# 836  21.0   8.6625
# 639   NaN  16.1000
# 389  17.0  12.0000
# 597  49.0   0.0000
# ..    ...      ...
# 131  20.0   7.0500
# 490   NaN  19.9667
# 838  32.0  56.4958
# 48    NaN  21.6792
# 80   22.0   9.0000
#
# [623 rows x 2 columns]

# %%
numeric_transformer.fit_transform(X_train, y_train)#y train沒處理>沒該欄位
# Out:
#       Age     Fare
# 231  29.0   7.7750
# 836  21.0   8.6625
# 639   NaN  16.1000
# 389  17.0  12.0000
# 597  49.0   0.0000
# ..    ...      ...
# 131  20.0   7.0500
# 490   NaN  19.9667
# 838  32.0  56.4958
# 48    NaN  21.6792
# 80   22.0   9.0000
#
# [623 rows x 2 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
numeric_transformer = Pipeline(steps=[
    ('columns selector', ColumnsSelector(['Age','Fare'])),
    ('imputer', SimpleImputer(strategy='median')),
])
numeric_transformer.fit_transform(X_train)
# Out:
# array([[29.    ,  7.775 ],
#        [21.    ,  8.6625],
#        [28.75  , 16.1   ],
#        ...,
#        [32.    , 56.4958],
#        [28.75  , 21.6792],
#        [22.    ,  9.    ]])

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
numeric_transformer = Pipeline(steps=[
    ('columns selector', ColumnsSelector(['Age','Fare'])),
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
numeric_transformer.fit_transform(X_train)
# Out:
# array([[-0.02863633, -0.47911875],
#        [-0.65142052, -0.46270324],
#        [-0.04809833, -0.32513665],
#        ...,
#        [ 0.20490775,  0.42203815],
#        [-0.04809833, -0.22194182],
#        [-0.5735725 , -0.45646073]])

# %%
numeric_transformer.transform(X_test)
# Out:
# array([[-0.65142052, -0.47989005],
#        [-1.97483693,  0.09842973],
#        [ 3.20205667, -0.47958116],
#        [-0.41787645,  0.91519704],
#        [-0.06756034, -0.48921406],
#        [-0.80711657, -0.06803741],
#        [-0.04809833, -0.47958116],
#        [ 2.30680439, -0.37322716],
#        [-0.34002842,  2.18019377],
#        [ 1.60617218,  3.95530314],
#        [-1.04066064,  0.11114597],
#        [ 1.13908403, -0.47403226],
#        [-1.58559681,  0.01288412],
#        [-0.80711657, -0.38247533],
#        [-2.208381  , -0.33176389],
#        [-0.49572447, -0.47688439],
#        [-0.88496459,  3.58545385],
#        [-1.8969889 , -0.04237372],
#        [-0.04809833, -0.49252861],
#        [-0.49572447, -0.38247533],
#        [ 0.12705972,  2.42650409],
#        [-0.04809833, -0.47688439],
#        [ 0.12705972, -0.13739871],
#        [-0.88496459, -0.38247533],
#        [-2.208381  , -0.41700247],
#        [-0.49572447, -0.38247533],
#        [-0.34002842, -0.1420228 ],
#        [-2.208381  , -0.24236549],
#        [ 1.21693206, -0.13184981],
#        [-0.49572447, -0.36783177],
#        [ 0.74984391, -0.4763443 ],
#        [-0.41787645,  0.5793348 ],
#        [-0.04809833, -0.47403226],
#        [-0.72926854, -0.47765384],
#        [-1.42990076,  0.24455089],
#        [ 2.69604452,  4.24161182],
#        [ 1.6840202 , -0.47958116],
#        [-0.04809833, -0.48921406],
#        [ 2.03433631, -0.47403226],
#        [-0.41787645, -0.49083249],
#        [ 0.74984391, -0.4763443 ],
#        [-0.80711657, -0.1420228 ],
#        [ 0.12705972, -0.24329031],
#        [ 0.28275577, -0.46285676],
#        [ 1.9954123 , -0.32698629],
#        [-1.66344483, -0.23311732],
#        [ 2.07326032,  0.03369251],
#        [ 0.86661595, -0.35473081],
#        [ 1.45047613, -0.38247533],
#        [-0.18433238, -0.47873403],
#        [-0.65142052, -0.44120124],
#        [-0.04809833, -0.47981237],
#        [-0.04809833, -0.47403226],
#        [ 0.98338799, -0.48328043],
#        [-0.49572447, -0.3446355 ],
#        [-0.04809833, -0.05516765],
#        [ 1.45047613,  0.01288412],
#        [-0.88496459, -0.49807751],
#        [-0.41787645,  0.6588691 ],
#        [ 0.51629984, -0.13485546],
#        [-0.34002842, -0.47973468],
#        [ 1.76186823,  0.8247203 ],
#        [-1.11850866, -0.48929174],
#        [ 1.25585607, -0.09578193],
#        [-0.41787645, -0.31403884],
#        [-0.02863633, -0.47958116],
#        [ 0.98338799, -0.38247533],
#        [-1.97483693, -0.19751185],
#        [ 0.43845182, -0.4287162 ],
#        [ 0.12705972,  0.31106006],
#        [-0.18433238, -0.46270324],
#        [-0.65142052, -0.47873403],
#        [-0.65142052, -0.47765384],
#        [-0.04809833, -0.47688439],
#        [ 0.0492117 , -0.38247533],
#        [-0.65142052,  0.01288412],
#        [-0.18433238, -0.41700247],
#        [ 0.36060379, -0.35658044],
#        [ 1.37262811, -0.35473081],
#        [-0.04809833, -0.47888755],
#        [ 2.22895637, -0.07358631],
#        [-1.81914088, -0.01254836],
#        [-0.04809833, -0.19288776],
#        [ 0.12705972, -0.13739871],
#        [ 1.21693206, -0.47958116],
#        [-0.10648435, -0.47873403],
#        [-0.34002842,  0.14613551],
#        [-1.97483693, -0.41700247],
#        [-1.50774878, -0.17624104],
#        [-0.96281262, -0.46270324],
#        [ 1.45047613,  0.10952754],
#        [-0.5735725 , -0.48882934],
#        [-0.41787645, -0.38247533],
#        [-0.41787645, -0.27612133],
#        [ 1.06123601,  0.24455089],
#        [-0.04809833, -0.19288776],
#        [-0.41787645, -0.38247533],
#        [-0.88496459, -0.50277928],
#        [-1.74129286,  0.11114597],
#        [-1.11850866, -0.35557794],
#        [ 0.0492117 , -0.38247533],
#        [ 0.20490775, -0.1420228 ],
#        [-0.04809833, -0.47989005],
#        [ 0.51629984,  1.59663397],
#        [ 1.6840202 , -0.49245092],
#        [-0.04809833, -0.47403226],
#        [-0.18433238, -0.38247533],
#        [-0.04809833, -0.47688439],
#        [-0.04809833, -0.32513665],
#        [ 0.36060379, -0.02179653],
#        [ 0.86661595, -0.47958116],
#        [-0.04809833, -0.47688439],
#        [ 0.74984391, -0.04445456],
#        [-0.96281262, -0.35550211],
#        [-0.10648435,  0.24825016],
#        [-0.80711657, -0.62292786],
#        [ 1.29478008,  0.50858626],
#        [ 0.43845182, -0.13184981],
#        [ 2.77389254, -0.13184981],
#        [-0.34002842, -0.48929174],
#        [ 0.0492117 , -0.10965419],
#        [ 1.06123601, -0.13739871],
#        [ 1.91756427,  0.33633902],
#        [-0.04809833, -0.20938095],
#        [-0.10648435, -0.38247533],
#        [-1.97483693,  0.89115179],
#        [ 1.60617218, -0.47403226],
#        [-0.80711657, -0.47403226],
#        [-0.04809833, -0.48929174],
#        [-0.41787645, -0.45923518],
#        [-0.80711657, -0.49807751],
#        [ 1.21693206,  2.42650409],
#        [-0.2621804 , -0.35557794],
#        [-0.69034453, -0.48882934],
#        [-0.04809833, -0.48882934],
#        [-1.04066064, -0.44721255],
#        [-0.10648435, -0.44721255],
#        [-0.04809833,  0.84198295],
#        [ 1.45047613, -0.14333234],
#        [ 0.28275577,  1.04174351],
#        [-0.04809833, -0.39449796],
#        [-0.04809833, -0.62292786],
#        [ 1.60617218,  0.41101802],
#        [-2.13053298, -0.1420228 ],
#        [-0.65142052,  0.73655376],
#        [-0.41787645, -0.48428293],
#        [ 2.38465242,  0.09842973],
#        [-0.5735725 , -0.42840731],
#        [ 0.36060379, -0.47403226],
#        [-2.13053298, -0.39565398],
#        [-0.2621804 , -0.47765384],
#        [-0.34002842, -0.06803741],
#        [ 0.82769194, -0.33623446],
#        [-0.34002842, -0.47911875],
#        [ 0.20490775, -0.47403226],
#        [-0.41787645,  0.73655376],
#        [-1.58559681,  0.24455089],
#        [-0.65142052, -0.47403226],
#        [-0.88496459, -0.47958116],
#        [-0.04809833, -0.47981237],
#        [ 0.20490775,  0.78819002],
#        [-0.04809833, -0.343633  ],
#        [ 1.21693206, -0.35557794],
#        [-0.49572447, -0.47765384],
#        [ 0.12705972, -0.28999359],
#        [ 1.52832415,  0.43005447],
#        [-0.04809833,  0.66349318],
#        [-0.04809833,  1.42800831],
#        [-0.80711657, -0.47765384],
#        [-2.22784301, -0.26671963],
#        [-0.04809833, -0.62292786],
#        [ 0.51629984, -0.38247533],
#        [ 0.82769194,  1.86483102],
#        [ 1.21693206, -0.13739871],
#        [-0.04809833, -0.47958116],
#        [-0.18433238, -0.1420228 ],
#        [-0.2621804 , -0.27542771],
#        [ 2.77389254, -0.47958116],
#        [-0.34002842, -0.47688439],
#        [-0.04809833,  0.33888226],
#        [ 0.43845182, -0.23450454],
#        [-1.97483693, -0.3747679 ],
#        [ 0.28275577, -0.46270324],
#        [-0.18433238, -0.35557794],
#        [-0.04809833, -0.11019428],
#        [-0.41787645, -0.38247533],
#        [-0.88496459, -0.46940817],
#        [-0.04809833,  0.66349318],
#        [ 0.28275577, -0.44721255],
#        [ 1.91756427, -0.1420228 ],
#        [ 0.28275577, -0.47688439],
#        [-0.72926854, -0.44721255],
#        [-0.34002842, -0.49252861],
#        [-0.04809833, -0.20938095],
#        [ 0.59414787,  0.35922825],
#        [-0.04809833, -0.62292786],
#        [ 0.55522385, -0.1420228 ],
#        [ 1.60617218, -0.4287162 ],
#        [ 1.76186823, -0.05878923],
#        [-0.04809833, -0.47958116],
#        [ 0.12705972,  1.47224602],
#        [ 2.07326032, -0.05516765],
#        [-0.04809833, -0.47958116],
#        [-0.04809833, -0.47688439],
#        [-0.80711657, -0.35473081],
#        [-0.2621804 , -0.06803741],
#        [ 0.59414787, -0.1420228 ],
#        [ 0.0492117 , -0.47688439],
#        [-1.04066064,  0.01288412],
#        [ 0.20490775,  0.73655376],
#        [-0.80711657, -0.47403226],
#        [ 2.22895637,  2.21556803],
#        [ 1.45047613,  0.33888226],
#        [ 1.76186823, -0.37322716],
#        [-0.04809833, -0.47958116],
#        [ 0.74984391,  0.8503063 ],
#        [-1.58559681, -0.04237372],
#        [-1.8969889 , -0.26671963],
#        [ 0.36060379, -0.1420228 ],
#        [-1.19635669, -0.06672786],
#        [-0.04809833, -0.47719143],
#        [ 0.67199589, -0.46270324],
#        [ 0.67199589,  1.04174351],
#        [-0.04809833, -0.1420228 ],
#        [-0.41787645, -0.47403226],
#        [-0.04809833, -0.47688439],
#        [-0.04809833, -0.47958116],
#        [-0.65142052,  0.81901603],
#        [ 2.61819649, -0.44559412],
#        [ 3.24098068,  0.0180483 ],
#        [-0.49572447, -0.41021985],
#        [-0.34002842, -0.47911875],
#        [-0.72926854, -0.44120124],
#        [-0.34002842, -0.4814308 ],
#        [-0.04809833,  0.66349318],
#        [ 1.37262811, -0.48882934],
#        [ 1.45047613, -0.47765384],
#        [ 0.82769194, -0.04954106],
#        [-0.04809833, -0.47403226],
#        [-0.5735725 , -0.48882934],
#        [-0.04809833,  0.42203815],
#        [-0.04809833,  1.02517448],
#        [-0.02863633,  0.60892895],
#        [-1.81914088, -0.04445456],
#        [-0.04809833, -0.33623446],
#        [-0.10648435, -0.37322716],
#        [ 1.91756427,  0.47575524],
#        [-0.5735725 ,  2.18019377],
#        [ 0.0492117 ,  0.43005447],
#        [-0.10648435,  0.03369251],
#        [ 0.28275577, -0.24329031],
#        [-0.72926854, -0.46270324],
#        [-0.5735725 , -0.48382052],
#        [-0.04809833, -0.47688439],
#        [ 0.20490775, -0.47765384],
#        [ 0.90553996,  0.11114597],
#        [ 1.13908403, -0.11019428],
#        [-0.41787645, -0.1420228 ],
#        [ 0.39952781, -0.50385762],
#        [-0.72926854, -0.44081651],
#        [-0.04809833, -0.47958116],
#        [-1.04066064,  0.10582827],
#        [ 1.37262811, -0.45646073],
#        [-0.04809833, -0.47811625],
#        [-0.96281262, -0.46270324],
#        [ 0.51629984, -0.1367051 ],
#        [ 0.36060379, -0.47403226],
#        [-0.18433238, -0.05878923]])

# %%
class MyStandardScaler(BaseEstimator, TransformerMixin): 
    def __init__(self):
        return None
    
    def fit(self, X, y = None):
        print(type(X))
        # the type of X might be a DataFrame or a NumPy array
        # depending on the previous transformer object that 
        # you use in the pipeline
        self.means = np.mean(X, axis=0)    # calculate the mean
        self.stds = np.std(X, axis=0)      # calculate the 
                                           # standard deviation
        return self
    def transform(self, X, y = None):
        return (X - self.means) / self.stds

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
numeric_transformer = Pipeline(steps=[
    ('columns selector', ColumnsSelector(['Age','Fare'])),
    ('my scaler', MyStandardScaler())  
])
numeric_transformer.fit_transform(X_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           Age      Fare
# 231 -0.036551 -0.479119
# 836 -0.592408 -0.462703
# 639       NaN -0.325137
# 389 -0.870336 -0.400972
# 597  1.353091 -0.622928
# ..        ...       ...
# 131 -0.661890 -0.492529
# 490       NaN -0.253617
# 838  0.171895  0.422038
# 48        NaN -0.221942
# 80  -0.522926 -0.456461
#
# [623 rows x 2 columns]

# %%
from sklearn.utils.validation import check_is_fitted
class MyStandardScaler(BaseEstimator, TransformerMixin): 
    def __init__(self):
        return None
    
    def fit(self, X, y = None):
        print(type(X))
        # the type of X might be a DataFrame or a NumPy array
        # it depends on the previous transformer object that 
        # you use in the pipeline
        self.means = np.mean(X, axis=0)
        self.stds = np.std(X, axis=0)
        return self
    def transform( self, X, y = None ):
        check_is_fitted(self, ['means','stds'])
        return (X - self.means) / self.stds
numeric_transformer = Pipeline(steps=[
    ('columns selector', ColumnsSelector(['Age','Fare'])),
    ('imputer', SimpleImputer(strategy='median')),
    ('my scaler', MyStandardScaler())  
])
numeric_transformer.transform(X_train)##一定要fit
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21568/2672339500.py in <module>
#      20     ('my scaler', MyStandardScaler())
#      21 ])
# ---> 22 numeric_transformer.transform(X_train)
#
# ~\anaconda3\envs\py38_jq\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# --> 113             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114         else:
#     115
#
# ~\anaconda3\envs\py38_jq\lib\site-packages\sklearn\pipeline.py in transform(self, X)
#     645         Xt = X
#     646         for _, _, transform in self._iter():
# --> 647             Xt = transform.transform(Xt)
#     648         return Xt
#     649
#
# ~\anaconda3\envs\py38_jq\lib\site-packages\sklearn\impute\_base.py in transform(self, X)
#     466             `X` with imputed values.
#     467         """
# --> 468         check_is_fitted(self)
#     469
#     470         X = self._validate_input(X, in_fit=False)
#
# ~\anaconda3\envs\py38_jq\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1207
#    1208     if not fitted:
# -> 1209         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1210
#    1211
#
# NotFittedError: This SimpleImputer instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
